# %% [markdown]
# # Text Analytics Project

# %%
#Import packages
import pandas as pd
import nltk
nltk.download( 'vader_lexicon' )
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import seaborn as sns
import matplotlib.pyplot as plt
import ast
import timeit
import datetime
import numpy as np

from collections import Counter
import xlsxwriter
from pandas import DataFrame
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

import gensim
from gensim.utils import simple_preprocess
from gensim.parsing.preprocessing import STOPWORDS
from nltk.stem import WordNetLemmatizer, SnowballStemmer
from nltk.stem.porter import *
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\treyh\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
#Read in reviews datasets
reviews = pd.read_csv('C:/Users/treyh/OneDrive/Documents/Documents/IAA/Text Analytics/tiktok_app_reviews.csv')
weekly_scores = pd.read_csv('C:/Users/treyh/OneDrive/Documents/Documents/IAA/Text Analytics/perweek.csv')
scored_reviews = pd.read_csv('C:/Users/treyh/OneDrive/Documents/Documents/IAA/Text Analytics/scored_reviews.csv')

#Fix date and trim to after 2018
scored_reviews["posted_date"] = pd.to_datetime(scored_reviews["posted_date"])
scored_reviews["posted_date"] = scored_reviews["posted_date"].dt.date
scored_reviews = scored_reviews[scored_reviews["posted_date"] >= datetime.datetime.strptime('2018-01-01', "%Y-%m-%d").date()]
# Out:
# C:\Users\treyh\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3441: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Users\treyh\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3441: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
#Example of text with an emoji
reviews.iloc[29,1]
# Out:
# 'No glitches or hick ups as of yet, rather enjoying using the app 👍 Update, tried to log into my account via phone, says server error but our internet is fine, tried signing in with my facebook account, still server error, is the site under maintenance by any chance? Or will I need to uninstall then re-install?'

# %%
#Get scoring of example text
sentiment = SentimentIntensityAnalyzer()
score = sentiment.polarity_scores(reviews.iloc[327,1])
score
#print( score['neg'])
#print( score['pos'])
# Out:
# {'neg': 0.0, 'neu': 0.72, 'pos': 0.28, 'compound': 0.8126}

# %% [markdown]
# ## Modelling

# %%
plt.figure( figsize = ( 12, 5))
plt.plot(weekly_scores["Compound"] * (weekly_scores["upvotes"]))
#positive_avg

# %%
#Plot dip in time plot
test = weekly_scores[(weekly_scores["WeekDate"] >= '2020-06-01') & (weekly_scores["WeekDate"] <= '2020-06-15')]

plt.figure( figsize = ( 12, 5))
plt.plot(test["Compound"])

# %%
#Look at dataset around time of weird dip in the line plot
test2 = scored_reviews[(scored_reviews["posted_date"] >= datetime.datetime.strptime('2020-06-01', "%Y-%m-%d").date()) & (scored_reviews["posted_date"] <= datetime.datetime.strptime('2020-06-15', "%Y-%m-%d").date())]
test2
# Out:
#          Unnamed: 0                                          review_id  \
# 606780       606780  gp:AOqpTOFiFMv8Ds6OzJFwZfweMqyuIx9KlK0toZhAJoR...
# 656357       656357  gp:AOqpTOFYFq93ZQ_o1yRUC_6lKpfrgcZlSSE_ngUb6Ti...
# 770653       770653  gp:AOqpTOEkHjtiUhlFxN8A3b8xMCxwAD371oUaOh8qrwN...
# 792883       792883  gp:AOqpTOGChMoHAHEh7Q451z7rPwkUn8w4d1guY6R2woy...
# 798656       798656  gp:AOqpTOFPwTZQjIkzfJV2vYUsf-mdCvKEfLQWnMc6pam...
# 866941       866941  gp:AOqpTOHzHjobNNU7DGacAp1wtbAnO0yDQ14K1l09UOj...
# 1026280     1026280  gp:AOqpTOEy4dLrmOTe-c9PIu-DHxbtNlNvmKXDXONj5BF...
# 1069724     1069724  gp:AOqpTOE8X0pXze9VqsZmZw8NIDsqprG0LeAX2lAQmcp...
# 1135219     1135219  gp:AOqpTOEWg5e5-qcb-D2cy5GNgQLIg11uqYSH5_P-Jdr...
# 1217878     1217878  gp:AOqpTOHi3c9iIXlL4ZJiCOjWij5t2x4qRU2HTJiNiAy...
# 1233552     1233552  gp:AOqpTOFSY5Ict-niXVPL4pzV4Lu4uc5DW2LbAvnwVO2...
# 1542940     1542940  gp:AOqpTOGpY2c1D9gWIr298XH8Fmz1pN4no5qllDPavln...
# 1590674     1590674  gp:AOqpTOHC5LCgqXBP62nkUMQ3lbyx4tgFJU4iUS-UX4p...
# 1602652     1602652  gp:AOqpTOH5xaeO-c0DjtiBSCps8ro_CspARz1rflCoRXS...
# 2059258     2059258  gp:AOqpTOH3DHc5b_tJD2KQYokWRdrfDzxZtMTc-v_0Rrz...
# 2059265     2059265  gp:AOqpTOEqLxN3BfK63cL838pLe4EtEw5n1djwe6LqeNm...
# 2059327     2059327  gp:AOqpTOFVIOCSgxEkGVcwSlG8svF0IL0eG3KXxKGS3s0...
# 2059488     2059488  gp:AOqpTOH-cKW3UYe2VF5TFpeVrccBz9HF8jcqhOy7b9p...
# 2059647     2059647  gp:AOqpTOG1LN76AfQ3f9kjk3JyZm1sEzrHfaMAWAPjD-H...
# 2059652     2059652  gp:AOqpTOHyTIXXhCB7rLtJ8VcW1gdaeCNT6DOmvoj6DRs...
# 2060506     2060506  gp:AOqpTOF5UiSrbReuWeg0pbYfX7DrrgipAqy3AM7LwQH...
# 2061639     2061639  gp:AOqpTOGYN7x_DflP0WlxcwE8R32aOCEaXkyRUWGb9OD...
# 2063600     2063600  gp:AOqpTOHfqOhrNCoi4QMzwFCburCDj3U-MjCJqOyxgZB...
# 2064341     2064341  gp:AOqpTOEM2rObA7sTwW7kEwn8thd4UifqNbnZy-P5ad2...
# 2079477     2079477  gp:AOqpTOGHhAf2gMdgvFa194DsQs5qSwTedWQ5kxCvqof...
# 2095972     2095972  gp:AOqpTOHiQSv1NCMuiqhXzKidwCcCM3_lsCIUETS3msT...
# 2171603     2171603  gp:AOqpTOGnutFT9NPk2Tkeii4qx55GmgzFV8JOe-aIedp...
# 3171974     3171974  gp:AOqpTOE3cPLfMJ0Bn8_QdjrVXo-k0DBlkPIim3ZPp8j...
# 3235088     3235088  gp:AOqpTOGZmNMU5ha2PIfeAt5PGMzNGqe7eiH3NvNVMm7...
# 3252763     3252763  gp:AOqpTOFny27uifGhr1gfxF4II9GXAjz3NmF1ebLGsre...
#
#                                                review_text  upvotes  \
# 606780                             Super and excellent app        1
# 656357   I have complete 2k followers but still i dont ...        0
# 770653                       Amazing app very entertaining       23
# 792883                       So nice tiktok of the channel        3
# 798656                            It says bad words... Wtf        4
# 866941   Thos is lingnsokd mavi.si dkmfk mavsk malekidb...        0
# 1026280                                Nice to tik tok app        2
# 1069724         It's really bad.and net waste in this app.        2
# 1135219                                 I like and love it        0
# 1217878  I have 4k fan But have live copsan (uesr id =@...        4
# 1233552                              Best app till date !!        1
# 1542940                           Please tik tok team view        0
# 1590674  Wow xlentttttttrrtttttt ur how create xlnt tic...        0
# 1602652                         I make gacha life vids UnU        0
# 2059258                                          Suprbbbbb        2
# 2059265                                             Bummmm        3
# 2059327                                               Nice        5
# 2059488                                              Super        1
# 2059647                                                ❤❤❤        3
# 2059652                                                ❤❤❤        1
# 2060506                                          Zøyå khåñ        6
# 2061639                                           Nice app        3
# 2063600                            Suuuppppeeeerrrrrrr😍😍😍😍        0
# 2064341                                               Nice        1
# 2079477  Muze live ka opsan nhi mila he mere 1k follows...        6
# 2095972                                             ❤❤❤❤❤❤        0
# 2171603                                           Suppprrr        0
# 3171974  Heloo team tiktok My Profile Surpassed 1 k fol...        0
# 3235088                                     Msbhsm Sguushn        0
# 3252763                                    Takshdeep Singh        1
#
#         app_version posted_date  Positive  Negative  Neutral  Compound
# 606780       16.4.4  2020-06-09     0.792     0.000    0.208    0.8225
# 656357       16.0.4  2020-06-10     0.000     0.000    1.000    0.0000
# 770653       16.3.5  2020-06-09     0.778     0.000    0.222    0.7902
# 792883       16.0.4  2020-06-01     0.382     0.000    0.618    0.4754
# 798656          NaN  2020-06-08     0.000     0.709    0.291   -0.8074
# 866941          NaN  2020-06-03     0.000     0.000    1.000    0.0000
# 1026280     16.0.43  2020-06-02     0.412     0.000    0.588    0.4215
# 1069724     16.0.43  2020-06-02     0.000     0.304    0.696   -0.4703
# 1135219         NaN  2020-06-02     0.770     0.000    0.230    0.7717
# 1217878      16.3.5  2020-06-11     0.277     0.000    0.723    0.5574
# 1233552         NaN  2020-06-02     0.545     0.000    0.455    0.6988
# 1542940      16.2.4  2020-06-02     0.365     0.000    0.635    0.3182
# 1590674      16.2.4  2020-06-15     0.664     0.000    0.336    0.8720
# 1602652     16.0.43  2020-06-11     0.000     0.000    1.000    0.0000
# 2059258      16.3.5  2020-06-13     0.000     0.000    1.000    0.0000
# 2059265      16.3.5  2020-06-11     0.000     0.000    1.000    0.0000
# 2059327      16.3.5  2020-06-08     1.000     0.000    0.000    0.4215
# 2059488      16.3.4  2020-06-02     1.000     0.000    0.000    0.5994
# 2059647      16.3.4  2020-06-06     0.000     0.000    1.000    0.0000
# 2059652      16.3.4  2020-06-09     0.000     0.000    1.000    0.0000
# 2060506      16.2.4  2020-06-07     0.000     0.000    1.000    0.0000
# 2061639      16.2.4  2020-06-05     0.737     0.000    0.263    0.4215
# 2063600     16.0.43  2020-06-13     0.000     0.000    1.000    0.0000
# 2064341     16.0.43  2020-06-02     1.000     0.000    0.000    0.4215
# 2079477      15.9.5  2020-06-03     0.000     0.000    1.000    0.0000
# 2095972      15.9.1  2020-06-10     0.000     0.000    1.000    0.0000
# 2171603      15.4.3  2020-06-11     0.000     0.000    1.000    0.0000
# 3171974         NaN  2020-06-03     0.329     0.060    0.611    0.9413
# 3235088         NaN  2020-06-14     0.000     0.000    1.000    0.0000
# 3252763         NaN  2020-06-11     0.000     0.000    1.000    0.0000

# %%
post_covid = scored_reviews[(scored_reviews["posted_date"] >= datetime.datetime.strptime('2020-03-01', "%Y-%m-%d").date()) ]
pre_covid = scored_reviews[(scored_reviews["posted_date"] < datetime.datetime.strptime('2020-03-01', "%Y-%m-%d").date()) ]
print(len(pre_covid["Compound"]), len(post_covid["Compound"]))
# Out:
# 1565533 1716534

# %%
q1, q3= np.percentile(post_covid["Compound"],[25,75])
iqr = q3-q1
iqr
lower_bound = q1 -(1.5 * iqr) 
upper_bound = q3 +(1.5 * iqr) 
print(lower_bound, upper_bound)
post_covid[post_covid["Neutral"] < post_covid["Negative"]]
# Out:
# -0.95535 1.59225
#          Unnamed: 0                                          review_id  \
# 1201           1201  gp:AOqpTOFVC91_Lrc5fK9JWFiK1P5qMSkO_CTftQb9aYK...
# 2430           2430  gp:AOqpTOFo0m0HNalqqQpROX18p7z3YX1A698i6Mp0C6P...
# 2576           2576  gp:AOqpTOH3aiMHpSsqXTg5-tKwbgHqfTzAy_18rVis9Rm...
# 2952           2952  gp:AOqpTOHBA3BU5TsG0bct5QYy6JQzlrMGsR1Oy3pdeIx...
# 3583           3583  gp:AOqpTOHMi7ThkJpSGeEJhjOxRgtREVILjsiuxF8jl-I...
# ...             ...                                                ...
# 3644731     3644731  gp:AOqpTOHwp6vGl-VvAgUxXArBM64-2qeutFRA8VPXgfL...
# 3644915     3644915  gp:AOqpTOFzKK397XYgItRBqQjqXZ8DWExc4wcr2Hd3d4A...
# 3644997     3644997  gp:AOqpTOHDeaDhMGIDJFIIayP6L8oQiZnvffuixyDN8MC...
# 3645758     3645758  gp:AOqpTOFJ0RnxAGePcxxBeoaK2uU-VefM5_2l7jOXsw9...
# 3646017     3646017  gp:AOqpTOFArW_4HgWy_RUmr1wN_-jm-VMkWPbLs8tXm6-...
#
#                                                review_text  upvotes  \
# 1201     No problems, no adds great pics videos between...        1
# 2430     Terrible app, account creation was difficult, ...        1
# 2576             Really good app with no upload problems 😊        0
# 2952     Absolutely love the app! No unwanted ads, no p...        2
# 3583     Great app but one problem payment schedule not...        0
# ...                                                    ...      ...
# 3644731                                                ass        0
# 3644915                                                Ass        0
# 3644997                                                IDK        0
# 3645758                                                Idk        0
# 3646017                                                zzz        0
#
#         app_version posted_date  Positive  Negative  Neutral  Compound
# 1201         20.9.3  2021-09-06     0.355     0.350    0.296    0.2732
# 2430         20.2.2  2021-07-01     0.147     0.440    0.414   -0.8313
# 2576        21.1.41  2021-09-12     0.264     0.405    0.331   -0.1796
# 2952         20.0.5  2021-06-28     0.227     0.470    0.303   -0.4213
# 3583         20.4.4  2021-07-21     0.162     0.457    0.381   -0.6860
# ...             ...         ...       ...       ...      ...       ...
# 3644731         NaN  2020-12-04     0.000     1.000    0.000   -0.5423
# 3644915         NaN  2020-10-10     0.000     1.000    0.000   -0.5423
# 3644997         NaN  2020-06-18     0.000     1.000    0.000   -0.1027
# 3645758         NaN  2021-09-16     0.000     1.000    0.000   -0.1027
# 3646017         NaN  2020-06-24     0.000     1.000    0.000   -0.2960
#
# [20834 rows x 10 columns]

# %%
pos_pre = pre_covid.nlargest(1000, "Compound")
neg_pre = pre_covid.nsmallest(1000, "Compound")
pos_post = post_covid.nlargest(1000, "Compound")
neg_post = post_covid.nsmallest(1000, "Compound")

# %%
pos_post["review_text"] * (pos_post["upvotes"] + 1)
# Out:
# 659947     How to make pickle make your day good I like I...
# 127336     Like To do that you can see two different ways...
# 489312     Lovely l like this l love tiktok thanka you ar...
# 508217     I had a problem with this I have 4 account i n...
# 1128414    Hi I know it's going well and it is my first t...
#                                  ...
# 121520     This is a super entertaining app we all love i...
# 132490     It's soo fun and I love it like I can not slee...
# 161961     i love the app dont listen to those who say th...
# 163195     When i was joined tiktok. Reay it's make my li...
# 190668     overall its really good like its a amazing app...
# Length: 1000, dtype: object

# %%
from nltk.corpus import stopwords

counter = Counter(" ".join((neg_post["review_text"]*(neg_post["upvotes"] + 1)).astype(str)).split()).most_common(1000)
filtered_words_all = []
for (word, count) in counter:
    if word.lower() not in stopwords.words('english'):
        filtered_words_all.append(tuple((word, count)))

# %%
filtered_words_all
# Out:
# [('big', 12102),
#  ('videos', 11358),
#  ('app', 11125),
#  ('problem', 8999),
#  ('really', 8489),
#  ('people', 7329),
#  ('bad', 5780),
#  ('comments', 4985),
#  ('things', 4900),
#  ('tiktok', 4558),
#  ('many', 4557),
#  ('problems', 4467),
#  ('video', 4336),
#  ('getting', 4293),
#  ('another', 4251),
#  ('feel', 4205),
#  ('say', 4170),
#  ('creators', 4124),
#  ('deleted', 4105),
#  ('favorite', 4098),
#  ('problems.', 4094),
#  ('hours', 4090),
#  ('spend', 4062),
#  ('always', 4062),
#  ('mean', 4055),
#  ('deleting', 4043),
#  ('without', 4042),
#  ('reason,', 4041),
#  ('random', 4037),
#  ('me,', 4033),
#  ('bored,', 4032),
#  ('example', 4032),
#  ('bothers', 4032),
#  ('bugs', 4032),
#  ('amazing!!', 4031),
#  ('interesting', 4031),
#  ('problems,', 4031),
#  ('minor', 4031),
#  ('community,', 4031),
#  ('them.This', 4029),
#  ('still', 3871),
#  ('know', 3648),
#  ('much', 3623),
#  ('using', 3238),
#  ('screen', 3225),
#  ('dont', 3142),
#  ('let', 3128),
#  ('im', 3097),
#  ('tried', 3079),
#  ('like', 3078),
#  ('log', 3048),
#  ('it,', 3042),
#  ('says', 3033),
#  ('great', 2965),
#  ('watching', 2935),
#  ('try', 2920),
#  ('good.', 2919),
#  ('But,', 2908),
#  ('black', 2905),
#  ('long', 2901),
#  ('uninstalled', 2895),
#  ('doesnt', 2894),
#  ('again.', 2888),
#  ('white', 2887),
#  ('VIDEOS', 2887),
#  ('internet,', 2886),
#  ('something.', 2886),
#  ('but..IT', 2885),
#  ('DOESNT', 2885),
#  ('LET', 2885),
#  ('WATCH', 2885),
#  ('ANYMORE!', 2885),
#  ('line', 2885),
#  ('bottom.', 2885),
#  ('checked', 2885),
#  ('worse!', 2885),
#  ('service', 2885),
#  ('acocunt,', 2885),
#  ('problem!This', 2884),
#  ('good', 1603),
#  ('get', 1553),
#  ('thing', 1550),
#  ('think', 1525),
#  ('time', 1040),
#  ('watch', 1016),
#  ('see', 929),
#  ("can't", 835),
#  ('would', 804),
#  ('going', 780),
#  ('amazing', 746),
#  ('app.', 716),
#  ('videos.', 699),
#  ('nice', 686),
#  ('nasty', 679),
#  ('hate', 675),
#  ('happening', 662),
#  ('come', 660),
#  ('body', 655),
#  ('wish', 653),
#  ('opinion', 652),
#  ('posted', 652),
#  ('personally', 646),
#  ('judged', 646),
#  ('cruel', 646),
#  ('Varietys', 645),
#  ('follow,', 645),
#  ('types', 645),
#  ('miserable', 645),
#  ('shamed,', 645),
#  ('race', 645),
#  ('generally', 645),
#  ('people,I', 645),
#  ('tiktok!!A', 644),
#  ('bullying', 588),
#  ('cyber', 561),
#  ('fix', 542),
#  ('please', 540),
#  ('ever', 539),
#  ('live', 529),
#  ('report', 469),
#  ("there's", 465),
#  ('love', 457),
#  ('also', 453),
#  ('need', 438),
#  ('followers', 426),
#  ('gave', 420),
#  ('banned', 412),
#  ('go', 411),
#  ('course', 407),
#  ('accounts', 391),
#  ('new', 390),
#  ("I'm", 383),
#  ('keep', 381),
#  ('definitely', 381),
#  ('problem.', 376),
#  ('app!', 375),
#  ('person', 374),
#  ('worked', 374),
#  ('looking', 369),
#  ('face', 367),
#  ('anything', 366),
#  ('want', 351),
#  ('us', 350),
#  ('spending', 341),
#  ('100%', 341),
#  ('wifi,', 340),
#  ('stay', 340),
#  ('help.', 340),
#  ('afar', 339),
#  ('glasses', 339),
#  ('pressed', 339),
#  ('trouble', 339),
#  ('repressing', 339),
#  ('suicidal', 339),
#  ('tendencies', 339),
#  ('quarantine', 339),
#  ('pass', 339),
#  ('distracted', 339),
#  ('attention', 339),
#  ("span's", 339),
#  ('shortened', 339),
#  ("Let's", 339),
#  ('alive', 339),
#  ("y'all.Sure.", 338),
#  ('help', 334),
#  ('lost', 326),
#  ('make', 319),
#  ('something', 313),
#  ('und', 313),
#  ('although', 311),
#  ('experience', 309),
#  ('send', 308),
#  ('account', 306),
#  ('never', 304),
#  ('put', 303),
#  ('taken', 301),
#  ('show', 299),
#  ('comment', 295),
#  ('use', 291),
#  ('someone', 290),
#  ('ok', 290),
#  ('super', 283),
#  ('bullied,', 281),
#  ('far,', 280),
#  ('generation', 280),
#  ('satisfactory,', 279),
#  ('atuomaticly', 279),
#  ('out,', 279),
#  ("we're", 279),
#  ('tik', 278),
#  ('problem!My', 278),
#  ('takes', 277),
#  ('fun', 276),
#  ('stars', 270),
#  ('u', 269),
#  ('one', 267),
#  ('die', 264),
#  ('better', 263),
#  ('ban', 262),
#  ('it.', 259),
#  ('stuff', 254),
#  ('connection', 254),
#  ('click', 252),
#  ('net', 251),
#  ('storage', 251),
#  ('profile', 249),
#  ('phone', 248),
#  ('es', 248),
#  ('worst', 247),
#  ('even', 244),
#  ('find', 242),
#  ('last', 240),
#  ('post', 238),
#  ('network', 237),
#  ('fixed', 236),
#  ('view', 230),
#  ('five', 228),
#  ('10', 228),
#  ('2', 226),
#  ('internet', 226),
#  ('cool', 224),
#  ('APP', 224),
#  ('made', 223),
#  ('Please', 221),
#  ('jealous', 220),
#  ('seems', 219),
#  ('hater', 219),
#  ('weeks', 219),
#  ('cannot', 218),
#  ('obtained', 217),
#  ('gifts', 217),
#  ('nearly', 217),
#  ('TIKOK😅Every', 216),
#  ('update.Sometimes', 216),
#  ('opens', 216),
#  ('network.Alsi', 216),
#  ('lesser', 216),
#  ('specified.The', 216),
#  ('tiktik', 216),
#  ('you😭I', 216),
#  ('everyday.With', 216),
#  ('Rate', 216),
#  ('❤ADDICTED', 215),
#  ("what's", 215),
#  ('Tiktok', 214),
#  ('creating', 214),
#  ('could', 212),
#  ('fair', 204),
#  ('around', 202),
#  ('fake', 201),
#  ('blocking', 201),
#  ('great!!maybe', 199),
#  ('favorites', 199),
#  ('🤷', 199),
#  ('limit', 199),
#  ('follow?Little', 199),
#  ('errors', 199),
#  ('maybe?do', 199),
#  ('agree', 199),
#  ('hell', 198),
#  ('not?yes?no?AMIZING', 198),
#  ('look', 197),
#  ("that's", 195),
#  ('page', 193),
#  ('different', 191),
#  ('thats', 189),
#  ('trying', 186),
#  ("I've", 186),
#  ('lot', 184),
#  ('star', 184),
#  ('bored', 179),
#  ('working', 178),
#  ('mobile', 178),
#  ('idk', 177),
#  ('looks', 177),
#  ('suddenly', 175),
#  ('Nothing', 175),
#  ('fast', 174),
#  ('annoying', 173),
#  ('quality', 173),
#  ('id', 173),
#  ('data,', 171),
#  ('-', 171),
#  ('machen', 169),
#  ('noch', 169),
#  ('auch', 169),
#  ('years,', 169),
#  ('error.', 169),
#  ('Tried', 169),
#  ('clearing', 169),
#  ('cache,', 169),
#  ('reinstalling,', 169),
#  ('checking', 169),
#  ('permissions,', 169),
#  ('proxy', 169),
#  ('network..', 169),
#  ('government', 169),
#  ('isp', 169),
#  ('Guess', 169),
#  ('resolves', 169),
#  ('itself.', 169),
#  ('Galaxy', 169),
#  ('S9', 169),
#  ('South', 169),
#  ('für', 168),
#  ('oder', 168),
#  ('today', 168),
#  ('KoreaUsed', 168),
#  ('reported', 167),
#  ('scroll', 165),
#  ('response', 164),
#  ('message', 163),
#  ('God', 163),
#  ('pls', 163),
#  ('follow', 162),
#  ('becomes', 162),
#  ('everything', 161),
#  ('edit', 161),
#  ('on.', 160),
#  ('thru', 160),
#  ('endlessly', 160),
#  ('awful', 160),
#  ('searching', 160),
#  ('results', 160),
#  ('content', 159),
#  ('plus', 159),
#  ('account,', 159),
#  ('4', 159),
#  ('problemThis', 159),
#  ('able', 158),
#  ('slow', 158),
#  ('setting', 157),
#  ('hard,', 157),
#  ('support', 156),
#  ('wrong,', 156),
#  ('everything.', 156),
#  ('in,', 156),
#  ('followed,', 156),
#  ('time,', 156),
#  ('working.', 156),
#  ('scared,', 156),
#  ('restart', 156),
#  ('hard.', 156),
#  ('because.', 156),
#  ('option.', 156),
#  ('responding.', 156),
#  ('possible.', 156),
#  ('wise.Tiktok', 155),
#  ('11.8k', 155),
#  ('slove', 155),
#  ('@shinu945', 155),
#  ('needs', 154),
#  ('report.Good', 154),
#  ('system', 150),
#  ('kids', 149),
#  ('play', 149),
#  ('allow', 148),
#  ('social', 148),
#  ('user', 145),
#  ('careful', 144),
#  ('gibt', 143),
#  ('Also', 140),
#  ('especially', 140),
#  ('funny', 138),
#  ('room', 138),
#  ('become', 138),
#  ('serious', 137),
#  ('certain', 136),
#  ('favourite', 135),
#  ('inconvenient', 135),
#  ('conditions', 135),
#  ('avoiding', 135),
#  ('disappointing.', 135),
#  ('allocated', 135),
#  ('senior', 135),
#  ('chatters.', 135),
#  ('hand', 135),
#  ('facilitates', 135),
#  ('bigotry', 135),
#  ('one.Tiktok', 134),
#  ('goes', 134),
#  ('kill', 132),
#  ('reason', 132),
#  ('ever,', 130),
#  ('sometimes', 129),
#  ('contract', 129),
#  ('forever', 129),
#  ('it!!!', 129),
#  ('tok', 128),
#  ('seen???', 128),
#  ('universe', 128),
#  ('forever,', 128),
#  ('will!!!', 128),
#  ('created,', 128),
#  ('exist', 128),
#  ('there!!!', 128),
#  ('Remember', 128),
#  ('etched', 128),
#  ('brain,', 128),
#  ('erase', 128),
#  ('death,', 128),
#  ('violence,', 128),
#  ('whether', 128),
#  ('unknowingly', 128),
#  ('agreed', 128),
#  ('Devil!!!', 128),
#  ('Remember?', 128),
#  ('Universe', 128),
#  ('ends,', 128),
#  ('andere', 127),
#  ('peaceShould', 127),
#  ('games', 125),
#  ('YouTube', 125),
#  ('barely', 124),
#  ('1.0GB', 124),
#  ('download', 123),
#  ("phone.It's", 123),
#  ('man', 121),
#  ('well', 118),
#  ('Tik', 117),
#  ('got', 116),
#  ('toks', 116),
#  ('since', 115),
#  ('nothing', 115),
#  ('blocked', 114),
#  ('stop', 112),
#  ('richtig', 112),
#  ('wird', 112),
#  ('trends', 110),
#  ('days', 109),
#  ('.', 107),
#  ('open', 104),
#  ('hard', 104),
#  ('way', 102),
#  ('5', 101),
#  ('work', 101),
#  ('used', 101),
#  ('Tok', 100),
#  ('apps', 99),
#  ('anyone', 95),
#  ('issues', 93),
#  ('solve', 92),
#  ('words', 89),
#  ('zu', 87),
#  ('currently', 87),
#  ('give', 86),
#  ('viele', 86),
#  ('block', 82),
#  ('take', 81),
#  ('okay', 80),
#  ('girls', 79),
#  ('girl', 78),
#  ('died', 77),
#  ('toxic', 74),
#  ('Es', 73),
#  ('telling', 72),
#  ('upset', 72),
#  ('type', 72),
#  ('calling', 71),
#  ('ist', 71),
#  ('stupid', 70),
#  ("they're", 70),
#  ('entertaining', 70),
#  ('mind', 69),
#  ('end', 68),
#  ('community', 68),
#  ('s***', 68),
#  ('f***', 68),
#  ('dumb', 67),
#  ('tiktokers', 67),
#  ('heard', 66),
#  ('pleasent', 66),
#  ('connection.', 66),
#  ('but,', 65),
#  ('okay.', 65),
#  ('views', 65),
#  ('worstI', 65),
#  ('every', 65),
#  ('cats', 64),
#  ('💀', 64),
#  ('problematic', 64),
#  ('alot', 64),
#  ('throwing', 63),
#  ('cat', 63),
#  ('😳.', 63),
#  ('RIP.', 63),
#  ('Zoe', 63),
#  ('Laverne.', 63),
#  ('Fandom', 63),
#  ('"The', 63),
#  ('Dunkins".', 63),
#  ('Fandoms', 63),
#  ('speaking', 63),
#  ('lbgq+', 63),
#  ('blm.', 63),
#  ('blm', 63),
#  ('trend..', 63),
#  ('first', 63),
#  ('update', 62),
#  ('problemsTiktok', 62),
#  ('depressed', 62),
#  ('plain', 61),
#  ('musically', 60),
#  ('seen', 60),
#  ('appeal', 60),
#  ('acc', 59),
#  ('sick', 59),
#  ('content,', 59),
#  ('tok.', 59),
#  ('interested', 59),
#  ('guys', 58),
#  ('da', 58),
#  ('violation.', 58),
#  ('Everytime', 58),
#  ('winning', 58),
#  ('dedicating', 58),
#  ('140k', 58),
#  ('terrified', 58),
#  ('envious.', 58),
#  ('Plenty', 58),
#  ('boat', 58),
#  ('right', 57),
#  ('me.Love', 57),
#  ('toll', 56),
#  ('kann', 56),
#  ('gehen', 56),
#  ('mehr', 56),
#  ('Trends.jetzt', 56),
#  ('einen', 56),
#  ('Trend', 56),
#  ('wo', 56),
#  ('Welt', 56),
#  ('schützen', 56),
#  ('soll', 56),
#  ('gab', 56),
#  ('Trends', 56),
#  ('alle', 56),
#  ('Spaß', 56),
#  ('nach', 56),
#  ('machen.es', 56),
#  ('BLM', 56),
#  ('MLM', 56),
#  ('Nationalitäten', 56),
#  ('unterstützt', 56),
#  ('verschiedenen', 56),
#  ('Sexualitäten.es', 56),
#  ('weiter', 56),
#  ('geholfen', 56),
#  ('mehr!Ich', 56),
#  ('empfehle', 56),
#  ('sehr!', 56),
#  ('Hilft', 56),
#  ('gegen', 56),
#  ('likes', 55),
#  ('absolutely', 55),
#  ('fact', 55),
#  ('LangeweileDie', 55),
#  ('back', 55),
#  ('day', 54),
#  (':(', 53),
#  ('sad', 53),
#  ('ads', 53),
#  ('messages', 53),
#  ('change', 53),
#  ('cuz', 52),
#  ('times', 51),
#  ('seeing', 51),
#  ('old', 50),
#  ('came', 50),
#  ('wrong', 49),
#  ('talk', 48),
#  ('remove', 48),
#  ('wearing', 48),
#  ('dancing', 48),
#  ('hear', 47),
#  ('self', 47),
#  ('already', 47),
#  ('ad', 47),
#  ('exept', 47),
#  ('shorts', 47),
#  ('tshirt', 47),
#  ('Charlie', 47),
#  ("d'amilio", 47),
#  ('avani', 47),
#  ('technically', 47),
#  ('naked', 47),
#  ('(wearing', 47),
#  ('bikinis)', 47),
#  ('saying', 46),
#  ('unfairIve', 46),
#  ("people's", 44),
#  ('little', 44),
#  ('best', 44),
#  ("y'all", 42),
#  ('option', 42),
#  ('tictok', 42),
#  ('ass', 42),
#  ('negative', 42),
#  ('life', 41),
#  ('tick', 41),
#  ('uploaded', 41),
#  ('everybody', 40),
#  ('ticket', 39),
#  ('putting', 39),
#  ('duet', 39),
#  ('cant', 38),
#  ('Plz', 38),
#  ('that.', 38),
#  ('app,', 37),
#  ('tock', 37),
#  ('3', 36),
#  ('done', 36),
#  ('facing', 36),
#  ('installed', 36),
#  ('money', 35),
#  ('sentence', 35),
#  ('found', 35),
#  ('call', 35),
#  ('book', 35),
#  ('cost', 35),
#  ('f******', 35),
#  ('forget', 35),
#  ('sound', 34),
#  (':-', 34),
#  ('wins', 34),
#  ('fishing', 34),
#  ('goddamn', 34),
#  ('packs', 34),
#  ('AAA', 34),
#  ('it!', 34),
#  ('steal', 34),
#  ('scam', 34),
#  ('abuse,', 34),
#  ('yall', 34),
#  ('wordsI', 34),
#  ('rude', 33),
#  ('dirtyThis', 33),
#  ('angry', 33),
#  ('mobile.but', 33),
#  ('bullied', 32),
#  ('haters', 32),
#  ('said', 32),
#  ("I'd", 32),
#  ('crazy', 32),
#  ('shaking', 32),
#  ('wont', 32),
#  ('coming', 32),
#  ('fine', 32),
#  ('texting', 32),
#  ('problem.I', 32),
#  ('captions.', 32),
#  ('caption', 32),
#  ('taking', 31),
#  ('Bad', 31),
#  ('ruin', 31),
#  ('completely', 31),
#  ('phone,', 31),
#  ('thier', 31),
#  ('names', 31),
#  ('myself.', 31),
#  ('guidelines', 31),
#  ('broke', 31),
#  (',', 30),
#  ('boyfriend', 30),
#  ('spammers', 30),
#  ('links.', 30),
#  ('including', 30),
#  ('stuff.', 30),
#  ('liking', 30),
#  ('unable', 30),
#  ('irritating', 30),
#  ('der', 30),
#  ('dances', 29),
#  ('remember', 29),
#  ('start', 29),
#  ('somehow', 29),
#  ('get.No', 29),
#  ('spreading', 29),
#  ('updated', 29),
#  ('normal', 29),
#  ('algorithm', 29),
#  ('myself,', 29),
#  ('insecure.', 29),
#  ('insecure', 29),
#  ('fallowing', 29),
#  ('vpn', 29),
#  ('Great', 29),
#  ('liked', 29),
#  ('unstable', 29),
#  ('occasionally', 29),
#  ('viral', 28),
#  ('safe', 28),
#  ('actual', 28),
#  ('disturbing', 28),
#  ('it...I', 28),
#  ("'ll", 28),
#  ('VPN', 28),
#  ('bzy', 28),
#  ('starsI', 28),
#  ('vn', 28),
#  ('dms', 28),
#  ('thanks😉love', 28),
#  ('❤stay', 28),
#  ('close', 28),
#  ('local', 28),
#  ('interest', 28),
#  ('Czech', 28),
#  ('now.I', 28),
#  ('restarted', 28),
#  ('popular', 27),
#  ('mad', 27),
#  ('must', 27),
#  ('lots', 27),
#  ('people,', 27),
#  ('communicate', 27),
#  ('gospel', 27),
#  ('internetThis', 27),
#  ('inappropriate', 27),
#  ('safe😷This', 27),
#  ('workmy', 27),
#  ('racist', 26),
#  ('rid', 26),
#  ('team', 26),
#  ('la', 26),
#  ('glitches', 26),
#  ('guideline', 26),
#  ('making', 25),
#  ('tell', 25),
#  ('broken', 25),
#  ('Good', 25),
#  ('follower', 25),
#  (':/', 25),
#  ('ppl', 24),
#  ('violations', 24),
#  ('plz', 24),
#  ('removed', 24),
#  ('words(never', 24),
#  ('experienced', 24),
#  ('words.This', 24),
#  ('nasty.', 23),
#  ('years', 23),
#  ('makes', 23),
#  ('verified', 23),
#  ('children', 23),
#  ('Love', 23),
#  ('Hate', 23),
#  ('hands', 23),
#  ('automatically', 23),
#  ('easy', 23),
#  ('wait', 23),
#  ('appThis', 23),
#  ('saying).this', 23),
#  ('gets', 22),
#  ('application', 22),
#  ('1', 22),
#  ('reply', 22),
#  ('LOT', 22),
#  ('work.', 22),
#  ('pfp', 22),
#  ('overall,', 22),
#  ('po', 21),
#  ('TikTok', 21),
#  ('HATE', 21),
#  ('number', 21),
#  ('reporting', 21),
#  ('violence', 21),
#  ('actually', 21),
#  ('anymore', 21),
#  ('free', 21),
#  ('nowhere', 21),
#  ('included', 21),
#  ('actors', 21),
#  ('busted', 21),
#  ('wasting', 21),
#  (':))Great', 21),
#  ('catch', 21),
#  ('rulec', 21),
#  ('gain', 21),
#  ('tiktok.', 20),
#  ('upload', 20),
#  ('year', 20),
#  ('famous', 20),
#  ('scary', 20),
#  ('evil', 20),
#  ('tic', 20),
#  ('buttsVery', 20),
#  ('Tic', 20),
#  ('small', 20),
#  ('teaching', 20),
#  ('including,', 20),
#  ('treating/animal', 20),
#  ('food,', 20),
#  ('different/acting', 20),
#  ('Even', 20),
#  ('que', 20),
#  ('sexual', 20),
#  ('celebrityThis', 20),
#  ('keeps', 19),
#  ('low', 19),
#  ('delete', 19),
#  ('theres', 19),
#  ('literally', 19),
#  ('young', 19),
#  ('bc', 19),
#  ('enjoy', 19),
#  ('application,', 19),
#  ('mask', 19),
#  ('women', 19),
#  ('tired', 19),
#  ("etc!It's", 19),
#  ('age', 19),
#  ('showing', 18),
#  ('ugly', 18),
#  ('suspended', 18),
#  ('text', 18),
#  ('none', 18),
#  ('voice', 18),
#  ('"been', 18),
#  ('long"', 18),
#  ('it.It', 18),
#  ('kind', 17),
#  ('1st', 17),
#  ('fyp', 17),
#  ('h', 17),
#  ('frightening', 17),
#  ('kidnap', 17),
#  ('Momo', 17),
#  ('waste', 17),
#  ("tiktokI'm", 17),
#  ('friends,', 17),
#  ('Whenever', 17),
#  ('regarding', 17),
#  ('1000', 17),
#  ('experiencing.', 17),
#  ('breaking', 17),
#  ('it.Love', 17),
#  ('video,', 17),
#  ('Still', 17),
#  ('death', 16),
#  ('drama', 16),
#  ('n', 16),
#  ('next', 16),
#  ('matter', 16),
#  ('gangIt', 16),
#  ('review', 16),
#  ('vids', 16),
#  ('thereif', 16),
#  ('violation', 16)]

# %%
df = DataFrame(filtered_words_all,columns=['Word','Count']).drop(0) 
df["WordCloud"] = (df['Word'] + " ") *df['Count']
df

text = " ".join(review for review in df.WordCloud)


wordcloud = WordCloud(stopwords = [""], collocations=False,max_font_size=50, max_words=30, background_color="black").generate(text)
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %% [markdown]
# ## Topic Detection

# %%
#Create subset for post-covid
topic_det_set = scored_reviews[(scored_reviews["posted_date"] >= datetime.datetime.strptime('2020-03-01', "%Y-%m-%d").date()) ]

# %%
############################################ Start of topic detection #####################################################
##Functions to perform lemmatize and stem preprocessing steps on the data set.
def lemmatize_stemming(text):
    return stemmer.stem(WordNetLemmatizer().lemmatize(text, pos='v'))
def preprocess(text):
    result = []
    for token in gensim.utils.simple_preprocess(text):
        if token not in gensim.parsing.preprocessing.STOPWORDS and len(token) > 3:
            result.append(lemmatize_stemming(token))
    return result

# %%
##Preview after preprocessing.
doc_sample = " ".join(neg_pre['review_text'].astype(str))
print('original document: ')
words = []
for word in doc_sample.split(' '):
    words.append(word)
#print(words)
print('\n\n tokenized and lemmatized document: ')
stemmer = SnowballStemmer('english')
#print(preprocess(doc_sample))
# Out:
# original document:
#
#
#  tokenized and lemmatized document:

# %%
##Preprocess the text

processed_docs = neg_pre['review_text'].astype(str).map(preprocess)
processed_docs[:10]

##Create a dictionary from ‘processed_docs’ containing the number of times a word appears in the training set.

dictionary = gensim.corpora.Dictionary(processed_docs)
count = 0
for k, v in dictionary.iteritems():
    print(k, v)
    count += 1
    if count > 10:
        break
        
##Filter dictionary by: less than 15 appearances, 100000 most frequent tokens
dictionary.filter_extremes(no_below=15, no_above=0.5, keep_n=100000)
# Out:
# 0 hate
# 1 take
# 2 chang
# 3 comment
# 4 exlent
# 5 good
# 6 immedi
# 7 letter
# 8 limit
# 9 minimum
# 10 perfect

# %%
## For each document we create a dictionary reporting how many words and how many times those words appear, save in bow_corpus

bow_corpus = [dictionary.doc2bow(doc) for doc in processed_docs]
bow_corpus[10]

bow_doc_10 = bow_corpus[1]
for i in range(len(bow_doc_10)):
    print("Word {} (\"{}\") appears {} time.".format(bow_doc_10[i][0], 
                                               dictionary[bow_doc_10[i][0]], 
                                                bow_doc_10[i][1]))
# Out:
# Word 2 ("chang") appears 2 time.
# Word 3 ("comment") appears 1 time.
# Word 4 ("good") appears 1 time.
# Word 5 ("stupid") appears 2 time.
# Word 6 ("thing") appears 1 time.

# %%
##Create tf-idf model object, then apply transformation to the entire corpus. Preview TF-IDF scores for our first document.

from gensim import corpora, models
tfidf = models.TfidfModel(bow_corpus)
corpus_tfidf = tfidf[bow_corpus]
from pprint import pprint
for doc in corpus_tfidf:
    pprint(doc)
    break
# Out:
# [(0, 0.9894357503223272), (1, 0.1449720524242288)]

# %%
##Train our lda model using gensim.models.LdaMulticore 

lda_model = gensim.models.LdaMulticore(bow_corpus, num_topics=10, id2word=dictionary, passes=2, workers=2)

##For each topic, we will explore the words occuring in that topic and its relative weight.

for idx, topic in lda_model.print_topics(-1):
    print('Topic: {} \nWords: {}'.format(idx, topic))
# Out:
# Topic: 0
# Words: 0.115*"good" + 0.101*"like" + 0.065*"thing" + 0.045*"time" + 0.038*"wrong" + 0.038*"problem" + 0.036*"get" + 0.030*"delet" + 0.027*"best" + 0.025*"suck"
# Topic: 1
# Words: 0.206*"video" + 0.103*"problem" + 0.039*"qualiti" + 0.035*"peopl" + 0.029*"think" + 0.029*"upload" + 0.028*"good" + 0.026*"view" + 0.026*"bulli" + 0.025*"post"
# Topic: 2
# Words: 0.106*"hate" + 0.058*"sick" + 0.055*"video" + 0.047*"kill" + 0.042*"download" + 0.040*"tiktok" + 0.039*"peopl" + 0.036*"best" + 0.032*"hell" + 0.030*"wrong"
# Topic: 3
# Words: 0.089*"stop" + 0.087*"video" + 0.046*"thing" + 0.041*"love" + 0.037*"amaz" + 0.034*"ban" + 0.029*"start" + 0.027*"like" + 0.025*"live" + 0.023*"tiktok"
# Topic: 4
# Words: 0.210*"hate" + 0.056*"worst" + 0.037*"time" + 0.036*"suck" + 0.035*"stupid" + 0.032*"updat" + 0.030*"phone" + 0.027*"great" + 0.026*"tiktok" + 0.023*"peopl"
# Topic: 5
# Words: 0.232*"like" + 0.068*"dont" + 0.051*"love" + 0.047*"peopl" + 0.037*"tiktok" + 0.028*"know" + 0.026*"problem" + 0.022*"think" + 0.021*"want" + 0.021*"hard"
# Topic: 6
# Words: 0.091*"want" + 0.079*"peopl" + 0.071*"kid" + 0.067*"girl" + 0.040*"hate" + 0.039*"go" + 0.035*"right" + 0.034*"kill" + 0.029*"know" + 0.026*"sick"
# Topic: 7
# Words: 0.191*"love" + 0.068*"peopl" + 0.061*"bulli" + 0.050*"work" + 0.041*"think" + 0.040*"time" + 0.036*"guy" + 0.035*"stop" + 0.023*"come" + 0.022*"want"
# Topic: 8
# Words: 0.083*"good" + 0.083*"peopl" + 0.064*"music" + 0.056*"video" + 0.053*"tiktok" + 0.050*"updat" + 0.038*"like" + 0.037*"block" + 0.030*"comment" + 0.028*"know"
# Topic: 9
# Words: 0.097*"music" + 0.088*"updat" + 0.080*"like" + 0.076*"account" + 0.071*"hate" + 0.047*"peopl" + 0.031*"chang" + 0.026*"say" + 0.022*"dumb" + 0.022*"go"

# %%
##Using tfdif instead of bow corpus

lda_model_tfidf = gensim.models.LdaMulticore(corpus_tfidf, num_topics=10, id2word=dictionary, passes=2, workers=4)
for idx, topic in lda_model_tfidf.print_topics(-1):
    print('Topic: {} Word: {}'.format(idx, topic))
# Out:
# Topic: 0 Word: 0.113*"music" + 0.102*"best" + 0.073*"updat" + 0.048*"want" + 0.047*"hate" + 0.031*"live" + 0.028*"phone" + 0.028*"like" + 0.027*"know" + 0.026*"love"
# Topic: 1 Word: 0.107*"stop" + 0.061*"block" + 0.054*"dumb" + 0.052*"tiktok" + 0.052*"star" + 0.051*"mean" + 0.050*"addict" + 0.038*"hate" + 0.033*"peopl" + 0.029*"game"
# Topic: 2 Word: 0.069*"like" + 0.055*"version" + 0.053*"bore" + 0.046*"problem" + 0.041*"post" + 0.041*"peopl" + 0.035*"feel" + 0.035*"tiktok" + 0.031*"video" + 0.029*"song"
# Topic: 3 Word: 0.112*"bulli" + 0.110*"video" + 0.078*"good" + 0.053*"peopl" + 0.037*"like" + 0.036*"problem" + 0.034*"think" + 0.025*"amaz" + 0.022*"hater" + 0.021*"work"
# Topic: 4 Word: 0.055*"dont" + 0.048*"know" + 0.041*"like" + 0.040*"ban" + 0.039*"love" + 0.037*"phone" + 0.034*"great" + 0.032*"cool" + 0.031*"hate" + 0.028*"follow"
# Topic: 5 Word: 0.050*"thing" + 0.050*"life" + 0.041*"ban" + 0.038*"right" + 0.037*"hat" + 0.036*"reason" + 0.036*"girl" + 0.032*"good" + 0.031*"problem" + 0.031*"video"
# Topic: 6 Word: 0.052*"delet" + 0.049*"like" + 0.047*"kid" + 0.041*"chang" + 0.038*"video" + 0.036*"kill" + 0.034*"updat" + 0.030*"account" + 0.029*"hate" + 0.029*"hard"
# Topic: 7 Word: 0.210*"hate" + 0.098*"stupid" + 0.051*"updat" + 0.024*"time" + 0.024*"peopl" + 0.023*"horribl" + 0.023*"like" + 0.022*"music" + 0.020*"qualiti" + 0.020*"video"
# Topic: 8 Word: 0.089*"love" + 0.058*"tiktok" + 0.052*"problem" + 0.044*"nice" + 0.043*"account" + 0.038*"like" + 0.038*"suck" + 0.033*"good" + 0.030*"say" + 0.030*"make"
# Topic: 9 Word: 0.124*"worst" + 0.055*"kill" + 0.054*"hell" + 0.049*"time" + 0.048*"lose" + 0.045*"thing" + 0.042*"sick" + 0.028*"peopl" + 0.028*"download" + 0.027*"word"

# %%
topic_det_set['review_text'][1]
# Out:
# "Great app works really well so many features so many new features lots of popular trends and so many things you can do on the app like find friends, post videos, get likes ,Duets, shares, and so much more so yes or even get sponsored on tik tok besides all the scams the app is pretty content and sometimes the foryou page won't load but other than that it's a great app that continues to improve so yes 5 Stars"

# %%
##We will check where our test document would be classified.

for index, score in sorted(lda_model[bow_corpus[1]], key=lambda tup: -1*tup[1]):
    print("\nScore: {}\t \nTopic: {}".format(score, lda_model.print_topic(index, 10)))
# Out:
# Score: 0.21757495403289795
# Topic: 0.279*"cool" + 0.039*"famous" + 0.030*"game" + 0.023*"music" + 0.022*"thing" + 0.021*"danc" + 0.021*"buena" + 0.021*"video" + 0.020*"friend" + 0.019*"post"
#
# Score: 0.1432441622018814
# Topic: 0.342*"good" + 0.040*"video" + 0.020*"thank" + 0.016*"viral" + 0.014*"kumar" + 0.012*"tiktok" + 0.011*"meri" + 0.011*"nahi" + 0.011*"foryou" + 0.009*"mere"
#
# Score: 0.1337837427854538
# Topic: 0.078*"enjoy" + 0.032*"goog" + 0.027*"yeet" + 0.025*"brilliant" + 0.024*"platform" + 0.022*"mejor" + 0.022*"encanta" + 0.019*"ajay" + 0.017*"mass" + 0.016*"talent"
#
# Score: 0.1274244785308838
# Topic: 0.430*"like" + 0.038*"follow" + 0.028*"year" + 0.020*"perfect" + 0.019*"dope" + 0.016*"live" + 0.014*"noic" + 0.014*"help" + 0.013*"okay" + 0.010*"instal"
#
# Score: 0.12209010869264603
# Topic: 0.713*"nice" + 0.040*"superb" + 0.024*"star" + 0.023*"supar" + 0.019*"bahut" + 0.013*"nise" + 0.009*"work" + 0.006*"updat" + 0.006*"hard" + 0.006*"liy"
#
# Score: 0.0827363133430481
# Topic: 0.603*"super" + 0.154*"great" + 0.087*"funni" + 0.025*"experi" + 0.012*"interest" + 0.007*"fabul" + 0.006*"nich" + 0.004*"tare" + 0.004*"make" + 0.004*"real"
#
# Score: 0.08268307894468307
# Topic: 0.375*"amaz" + 0.080*"addict" + 0.076*"supper" + 0.065*"applic" + 0.049*"wonder" + 0.046*"download" + 0.020*"awsm" + 0.016*"outstand" + 0.014*"accha" + 0.014*"mind"
#
# Score: 0.04331432655453682
# Topic: 0.275*"best" + 0.135*"excel" + 0.113*"app" + 0.101*"khan" + 0.025*"osam" + 0.020*"beauti" + 0.018*"ilov" + 0.009*"boss" + 0.008*"better" + 0.007*"popular"
#
# Score: 0.04320935904979706
# Topic: 0.291*"awesom" + 0.126*"entertain" + 0.115*"mast" + 0.073*"time" + 0.058*"bhai" + 0.046*"pass" + 0.015*"free" + 0.010*"goood" + 0.009*"akash" + 0.009*"faltu"

# %%
for index, score in sorted(lda_model_tfidf[bow_corpus[1]], key=lambda tup: -1*tup[1]):
    print("\nScore: {}\t \nTopic: {}".format(score, lda_model_tfidf.print_topic(index, 10)))
# Out:
# Score: 0.27190929651260376
# Topic: 0.028*"foryou" + 0.023*"follow" + 0.021*"kumar" + 0.019*"account" + 0.015*"tiktok" + 0.014*"video" + 0.013*"view" + 0.013*"live" + 0.013*"singh" + 0.011*"famous"
#
# Score: 0.16250212490558624
# Topic: 0.155*"addict" + 0.129*"video" + 0.105*"wonder" + 0.071*"viral" + 0.048*"interest" + 0.040*"dope" + 0.032*"noic" + 0.020*"danc" + 0.016*"thing" + 0.016*"friend"
#
# Score: 0.16150128841400146
# Topic: 0.140*"app" + 0.054*"star" + 0.052*"supar" + 0.039*"bhai" + 0.032*"osam" + 0.027*"nise" + 0.027*"work" + 0.026*"download" + 0.025*"naic" + 0.022*"mere"
#
# Score: 0.15360549092292786
# Topic: 0.553*"great" + 0.067*"supper" + 0.021*"awsm" + 0.015*"amez" + 0.015*"luck" + 0.012*"mind" + 0.012*"joss" + 0.011*"word" + 0.011*"unfreez" + 0.010*"blow"
#
# Score: 0.1195283755660057
# Topic: 0.098*"awsom" + 0.071*"happi" + 0.038*"king" + 0.038*"acha" + 0.023*"help" + 0.023*"life" + 0.019*"support" + 0.018*"platform" + 0.015*"bhot" + 0.014*"hard"
#
# Score: 0.05217614397406578
# Topic: 0.295*"best" + 0.258*"awesom" + 0.046*"thank" + 0.046*"khan" + 0.029*"experi" + 0.021*"جميل" + 0.015*"appp" + 0.010*"برنامج" + 0.010*"رائع" + 0.010*"تطبيق"
#
# Score: 0.03952417150139809
# Topic: 0.390*"cool" + 0.076*"enjoy" + 0.063*"time" + 0.057*"beauti" + 0.047*"pass" + 0.018*"free" + 0.018*"goog" + 0.012*"instal" + 0.011*"bore" + 0.010*"sure"
#
# Score: 0.031753577291965485
# Topic: 0.666*"super" + 0.117*"entertain" + 0.034*"perfect" + 0.009*"niec" + 0.008*"verri" + 0.006*"use" + 0.005*"stuff" + 0.005*"semma" + 0.005*"absolut" + 0.004*"muito"
